# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df_merged_data = pd.read_csv('Data/merged_data.csv')
df_merged_data.fillna(0, inplace=True)
df_merged_data.head()
# Out:
#                 borough  good_job  trust  fair_treatment  dealing_issues  \
# 0  Barking and Dagenham      0.47   0.80            0.66            0.68
# 1  Barking and Dagenham      0.44   0.77            0.66            0.64
# 2  Barking and Dagenham      0.50   0.78            0.70            0.70
# 3  Barking and Dagenham      0.47   0.75            0.70            0.66
# 4  Barking and Dagenham      0.50   0.77            0.71            0.66
#
#    quarter   year  year_int  Outcome_A no further action disposal  \
# 0      1.0  21-22      2021                                 120.0
# 1      2.0  21-22      2021                                  85.0
# 2      3.0  21-22      2021                                   0.0
# 3      1.0  22-23      2022                                  85.0
# 4      2.0  22-23      2022                                 121.0
#
#    Outcome_Arrest  ...  Outcome_Penalty Notice for Disorder  \
# 0            17.0  ...                                  0.0
# ...

# %%
label_encoder = LabelEncoder()
df_merged_data['borough'] = label_encoder.fit_transform(df_merged_data['borough'])
df_merged_data['year'] = label_encoder.fit_transform(df_merged_data['year'])

# %%
features = df_merged_data.drop(columns=['trust', 'quarter', 'Outcome_A no further action disposal'])
target = df_merged_data['trust']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
print('R2:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
# Out:
# R2: 0.84743428060681
# MAE: 0.02169014084507043
# MSE: 0.0009887323943661974
