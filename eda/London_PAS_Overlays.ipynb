# %%
import pandas as pd
import csv
import geopandas as gpd
import pandas as pd
import folium
from folium import Choropleth
import json
from IPython.display import display

# %%
# Loading all the data
metrpolitan_street = pd.read_csv(r"C:\Users\20223661\Downloads\metropolitan-street-merged.csv")
metrpolitan_street_stopsearch = pd.read_csv(r"C:\Users\20223661\Downloads\metropolitan-stop-and-search-merged.csv")
metrpolitan_outcomes = pd.read_csv(r"C:\Users\20223661\Downloads\metropolitan-outcomes-merged.csv")
filtered_stopsearch = pd.read_csv(r"C:\Users\20223661\Downloads\filtered_stop_and_search.csv")
pas_boroughs = pd.read_csv(r"C:\Users\20223661\Downloads\pas_boroughs.csv")
custody_arrests = pd.read_csv(r"C:\Users\20223661\Downloads\Custody_Arrests_2019_2024.csv", sep=";")
custody_disposals = pd.read_csv(r"C:\Users\20223661\Downloads\Custody_Disposals_2019_2024.csv", sep=";")
pupil_travel_distance = pd.read_csv(r"C:\Users\20223661\Downloads\pupil_home_school_distance.csv", sep=";")

gdf = gpd.read_file(r"C:\Users\20223661\Downloads\london-boroughs_1179.geojson")

# %%
# Make columns numerical
pas_boroughs['good_job'] = pd.to_numeric(pas_boroughs['good_job'], errors = 'coerce')
pas_boroughs['trust'] = pd.to_numeric(pas_boroughs['trust'], errors = 'coerce')
pas_boroughs['fair_treatment'] = pd.to_numeric(pas_boroughs['fair_treatment'], errors = 'coerce')
pas_boroughs['dealing_issues'] = pd.to_numeric(pas_boroughs['dealing_issues'], errors = 'coerce')
pupil_travel_distance['far away percentage'] = pupil_travel_distance['far away percentage'].astype(str).str.replace(',', '.').astype(float)

# Drop the unnecessary columns and rows
pas_boroughs = pas_boroughs[['borough', 'trust', 'good_job', 'dealing_issues', 'fair_treatment']]
pupil_travel_distance = pupil_travel_distance[['borough', 'far away percentage']]
pupil_travel_distance = pupil_travel_distance[pupil_travel_distance['borough'] != 'England']

# Calculate average scores for each borough
pas_boroughs_aggregated = pas_boroughs.groupby('borough').mean().reset_index()
pupil_travel_distance_aggregated = pupil_travel_distance.groupby('borough')['far away percentage'].mean().reset_index()

# %%
# Make sure borough names match
pupil_travel_distance_aggregated['borough'] = pupil_travel_distance_aggregated['borough'].str.strip()
pas_boroughs_aggregated['borough'] = pas_boroughs_aggregated['borough'].str.strip()

# Merge pas and travel df's
combined_df = pd.merge(pas_boroughs_aggregated, pupil_travel_distance_aggregated, on='borough')

# Merge pas and travel df's with GeoJSON df
merged_pas = gdf.merge(combined_df, left_on='name', right_on='borough', how='left')

# %%
def create_map(merged, column, colormap, title):
    m = folium.Map(location=[51.509865, -0.118092], zoom_start=10)
    folium.Choropleth(
        geo_data=merged.__geo_interface__,
        data=merged,
        columns=[merged.index, column],
        key_on='feature.id',
        fill_color=colormap,
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name=title,
    ).add_to(m)
    folium.LayerControl().add_to(m)
    return m

# Maps for each metric
good_job_map = create_map(merged_pas, 'good_job', 'YlGn', 'Average Good Job Score')
trust_map = create_map(merged_pas, 'trust', 'PuRd', 'Average Trust Score')
fair_treatment_map = create_map(merged_pas, 'fair_treatment', 'BuPu', 'Average Fair Treatment Score')
dealing_issues_map = create_map(merged_pas, 'dealing_issues', 'OrRd', 'Average Dealing Issues Score')
travel_percentage_map = create_map(merged_pas, 'far away percentage', 'GnBu', 'Percentages of pupils that have to travel far')

# Display maps i
display(good_job_map)
display(trust_map)
display(fair_treatment_map)
display(dealing_issues_map)
display(travel_percentage_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_999d816165860c20b981654c468b1568 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_999d816165860c20b981654c468b1568&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_999d816165860c20b981654c468b1568 = L.map(
#                 &quot;map_999d816165860c20b981654c468b1568&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b32147e1b210986104edb35509da1f89 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_999d816165860c20b981654c468b1568);
#
#
#             var choropleth_9762070574f005aa22ab05d3c4108b8d = L.featureGroup(
#                 {}
#             ).addTo(map_999d816165860c20b981654c468b1568);
#
#
#         function geo_json_eff62b88391816d8f125b581e2bbdeb0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;6&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;12&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;14&quot;: case &quot;20&quot;: case &quot;22&quot;: case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;5&quot;: case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;26&quot;: case &quot;28&quot;: case &quot;30&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_eff62b88391816d8f125b581e2bbdeb0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_eff62b88391816d8f125b581e2bbdeb0 = L.geoJson(null, {
#                 onEachFeature: geo_json_eff62b88391816d8f125b581e2bbdeb0_onEachFeature,
#
#                 style: geo_json_eff62b88391816d8f125b581e2bbdeb0_styler,
#         });
#
#         function geo_json_eff62b88391816d8f125b581e2bbdeb0_add (data) {
#             geo_json_eff62b88391816d8f125b581e2bbdeb0
#                 .addData(data)
#                 .addTo(choropleth_9762070574f005aa22ab05d3c4108b8d);
#         }
#             geo_json_eff62b88391816d8f125b581e2bbdeb0_add({&quot;bbox&quot;: [-0.510173, 51.28676, 0.333874, 51.691773], &quot;features&quot;: [{&quot;bbox&quot;: [-0.330756, 51.326464, -0.238745, 51.437291], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.31772, 51.393668], [-0.310869, 51.386188], [-0.307521, 51.37901], [-0.308695, 51.37545], [-0.314341, 51.374639], [-0.317505, 51.371971], [-0.318285, 51.363506], [-0.323753, 51.354413], [-0.328046, 51.352136], [-0.330534, 51.348421], [-0.328177, 51.344041], [-0.330756, 51.328856], [-0.328314, 51.326464], [-0.319307, 51.327812], [-0.30571, 51.335409], [-0.303903, 51.343253], [-0.299949, 51.347671], [-0.29282, 51.352528], [-0.291109, 51.356561], [-0.28536, 51.361072], [-0.285462, 51.364251], [-0.276584, 51.368809], [-0.271956, 51.372597], [-0.264702, 51.375624], [-0.260841, 51.379556], [-0.252373, 51.378898], [-0.245054, 51.380035], [-0.244175, 51.383492], [-0.238745, 51.386095], [-0.239707, 51.389295], [-0.241692, 51.393871], [-0.247425, 51.397578], [-0.244685, 51.404228], [-0.249385, 51.4
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f0c01df997da59bcd313de39d02e0ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f0c01df997da59bcd313de39d02e0ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f0c01df997da59bcd313de39d02e0ca = L.map(
#                 &quot;map_7f0c01df997da59bcd313de39d02e0ca&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7886292dc59747cf08ba5d9c37cc8669 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7f0c01df997da59bcd313de39d02e0ca);
#
#
#             var choropleth_9e33107029e493fa74010b679722a51b = L.featureGroup(
#                 {}
#             ).addTo(map_7f0c01df997da59bcd313de39d02e0ca);
#
#
#         function geo_json_b556610912afc879c8c30569821b2698_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;16&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;9&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;30&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;6&quot;: case &quot;7&quot;: case &quot;18&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;12&quot;: case &quot;27&quot;: case &quot;28&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11&quot;: case &quot;13&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;21&quot;: case &quot;25&quot;: case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b556610912afc879c8c30569821b2698_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b556610912afc879c8c30569821b2698 = L.geoJson(null, {
#                 onEachFeature: geo_json_b556610912afc879c8c30569821b2698_onEachFeature,
#
#                 style: geo_json_b556610912afc879c8c30569821b2698_styler,
#         });
#
#         function geo_json_b556610912afc879c8c30569821b2698_add (data) {
#             geo_json_b556610912afc879c8c30569821b2698
#                 .addData(data)
#                 .addTo(choropleth_9e33107029e493fa74010b679722a51b);
#         }
#             geo_json_b556610912afc879c8c30569821b2698_add({&quot;bbox&quot;: [-0.510173, 51.28676, 0.333874, 51.691773], &quot;features&quot;: [{&quot;bbox&quot;: [-0.330756, 51.326464, -0.238745, 51.437291], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.31772, 51.393668], [-0.310869, 51.386188], [-0.307521, 51.37901], [-0.308695, 51.37545], [-0.314341, 51.374639], [-0.317505, 51.371971], [-0.318285, 51.363506], [-0.323753, 51.354413], [-0.328046, 51.352136], [-0.330534, 51.348421], [-0.328177, 51.344041], [-0.330756, 51.328856], [-0.328314, 51.326464], [-0.319307, 51.327812], [-0.30571, 51.335409], [-0.303903, 51.343253], [-0.299949, 51.347671], [-0.29282, 51.352528], [-0.291109, 51.356561], [-0.28536, 51.361072], [-0.285462, 51.364251], [-0.276584, 51.368809], [-0.271956, 51.372597], [-0.264702, 51.375624], [-0.260841, 51.379556], [-0.252373, 51.378898], [-0.245054, 51.380035], [-0.244175, 51.383492], [-0.238745, 51.386095], [-0.239707, 51.389295], [-0.241692, 51.393871], [-0.247425, 51.397578], [-0.244685, 51.404228], [-0.249385, 5
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dec0b2e703399d5208e95b867148c8fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dec0b2e703399d5208e95b867148c8fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dec0b2e703399d5208e95b867148c8fe = L.map(
#                 &quot;map_dec0b2e703399d5208e95b867148c8fe&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3a65ab0eb5ca9c40b1cc160c7d35e76 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dec0b2e703399d5208e95b867148c8fe);
#
#
#             var choropleth_f0f99dbd6c33e329d300e1387d697c99 = L.featureGroup(
#                 {}
#             ).addTo(map_dec0b2e703399d5208e95b867148c8fe);
#
#
#         function geo_json_129262ce574afaf4503936e196ad98c2_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;14&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8856a7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;6&quot;: case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#810f7c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;9&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8c96c6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;25&quot;: case &quot;27&quot;: case &quot;28&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;21&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bfd3e6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ebcda&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_129262ce574afaf4503936e196ad98c2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_129262ce574afaf4503936e196ad98c2 = L.geoJson(null, {
#                 onEachFeature: geo_json_129262ce574afaf4503936e196ad98c2_onEachFeature,
#
#                 style: geo_json_129262ce574afaf4503936e196ad98c2_styler,
#         });
#
#         function geo_json_129262ce574afaf4503936e196ad98c2_add (data) {
#             geo_json_129262ce574afaf4503936e196ad98c2
#                 .addData(data)
#                 .addTo(choropleth_f0f99dbd6c33e329d300e1387d697c99);
#         }
#             geo_json_129262ce574afaf4503936e196ad98c2_add({&quot;bbox&quot;: [-0.510173, 51.28676, 0.333874, 51.691773], &quot;features&quot;: [{&quot;bbox&quot;: [-0.330756, 51.326464, -0.238745, 51.437291], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.31772, 51.393668], [-0.310869, 51.386188], [-0.307521, 51.37901], [-0.308695, 51.37545], [-0.314341, 51.374639], [-0.317505, 51.371971], [-0.318285, 51.363506], [-0.323753, 51.354413], [-0.328046, 51.352136], [-0.330534, 51.348421], [-0.328177, 51.344041], [-0.330756, 51.328856], [-0.328314, 51.326464], [-0.319307, 51.327812], [-0.30571, 51.335409], [-0.303903, 51.343253], [-0.299949, 51.347671], [-0.29282, 51.352528], [-0.291109, 51.356561], [-0.28536, 51.361072], [-0.285462, 51.364251], [-0.276584, 51.368809], [-0.271956, 51.372597], [-0.264702, 51.375624], [-0.260841, 51.379556], [-0.252373, 51.378898], [-0.245054, 51.380035], [-0.244175, 51.383492], [-0.238745, 51.386095], [-0.239707, 51.389295], [-0.241692, 51.393871], [-0.247425, 51.397578], [-0.244685, 51.404228], [-0.249385, 51.4
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b930fba9be94e004e0b20b3204ea6644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b930fba9be94e004e0b20b3204ea6644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b930fba9be94e004e0b20b3204ea6644 = L.map(
#                 &quot;map_b930fba9be94e004e0b20b3204ea6644&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c86d95045767581dc2bef9587b3464e8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b930fba9be94e004e0b20b3204ea6644);
#
#
#             var choropleth_f2751d6563d431294e0d3d197e9399e6 = L.featureGroup(
#                 {}
#             ).addTo(map_b930fba9be94e004e0b20b3204ea6644);
#
#
#         function geo_json_75d960f1a6a32b9d3dffb0e2914fde23_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;8&quot;: case &quot;23&quot;: case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e34a33&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;13&quot;: case &quot;15&quot;: case &quot;21&quot;: case &quot;30&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdbb84&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;9&quot;: case &quot;14&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;22&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;6&quot;: case &quot;7&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;12&quot;: case &quot;16&quot;: case &quot;28&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdd49e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_75d960f1a6a32b9d3dffb0e2914fde23_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_75d960f1a6a32b9d3dffb0e2914fde23 = L.geoJson(null, {
#                 onEachFeature: geo_json_75d960f1a6a32b9d3dffb0e2914fde23_onEachFeature,
#
#                 style: geo_json_75d960f1a6a32b9d3dffb0e2914fde23_styler,
#         });
#
#         function geo_json_75d960f1a6a32b9d3dffb0e2914fde23_add (data) {
#             geo_json_75d960f1a6a32b9d3dffb0e2914fde23
#                 .addData(data)
#                 .addTo(choropleth_f2751d6563d431294e0d3d197e9399e6);
#         }
#             geo_json_75d960f1a6a32b9d3dffb0e2914fde23_add({&quot;bbox&quot;: [-0.510173, 51.28676, 0.333874, 51.691773], &quot;features&quot;: [{&quot;bbox&quot;: [-0.330756, 51.326464, -0.238745, 51.437291], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0